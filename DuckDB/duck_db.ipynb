# %%
import duckdb

# Connect to DuckDB in-memory database
con = duckdb.connect()

# Path to your text file with forward slashes
csv_file_path = r'C:/Users/PC/Desktop/RAIS_PARCIAL_2023/RAIS_PARCIAL_2023/RAIS_VINC_ID_CENTRO_OESTE/RAIS_VINC_ID_CENTRO_OESTE.txt'

# Query to read the text file using DuckDB's built-in support with automatic CSV format detection
# Set ignore_errors=True to skip any problematic rows
df = con.execute(f"SELECT * FROM read_csv_auto('{csv_file_path}', ignore_errors=True)").fetchdf()

# Display the first few rows of the dataframe to check
print(df.head())

# %%
# !pip install fireducks
# Out:
# ERROR: Could not find a version that satisfies the requirement fireducks (from versions: none)
# ERROR: No matching distribution found for fireducks

# %%
import duckdb

# Connect to DuckDB in-memory database (no need to create a file)
con = duckdb.connect()

# Path to your CSV file
csv_file_path = r'C:\Users\PC\Desktop\RAIS_PARCIAL_2023\RAIS_PARCIAL_2023\RAIS_VINC_ID_CENTRO_OESTE\RAIS_VINC_ID_CENTRO_OESTE.txt'

# Query to read the CSV using DuckDB's built-in support
# You can perform SQL queries directly on the CSV file without creating a table first.
df = con.execute(f"SELECT * FROM '{csv_file_path}'").fetchdf()

# Show the result (first few rows of the dataframe)
print(df.head())

# %%
import duckdb

# Connect to DuckDB in-memory database (no need to create a file)
con = duckdb.connect()

# Path to your CSV file
csv_file_path = './NU_415360878_01OUT2024_31OUT2024.csv'

# Query to read the CSV using DuckDB's built-in support
# You can perform SQL queries directly on the CSV file without creating a table first.
df = con.execute(f"SELECT * FROM '{csv_file_path}'").fetchdf()

# Show the result (first few rows of the dataframe)
print(df.head())
# Out:
#         Data   Valor                         Identificador  \
# 0 2024-10-01   -5.00  66fc41f2-4718-465b-8026-4ca000223e01
# 1 2024-10-01  -12.73  66fc59da-72ce-4f41-ba07-73a5e6d0f3a8
# 2 2024-10-01   -5.00  66fc88e6-3301-424a-89d9-bcf35c957e5d
# 3 2024-10-03  400.00  66feda33-7263-4912-a915-91dc74e17517
# 4 2024-10-03 -114.18  66feda78-8c5b-4396-96a3-f64b12c108a8
#
#                                            Descrição
# 0  Transferência enviada pelo Pix - Aurilene Dos ...
# 1  Transferência enviada pelo Pix - SERVICO SOCIA...
# 2  Transferência enviada pelo Pix - Luciene Maced...
# 3  Transferência recebida pelo Pix - ZHANG YUAN -...
# 4  Pagamento de boleto efetuado - TOKIO MARINE SE...

# %%
df
# Out:
#          Data    Valor                         Identificador  \
# 0  2024-10-01    -5.00  66fc41f2-4718-465b-8026-4ca000223e01
# 1  2024-10-01   -12.73  66fc59da-72ce-4f41-ba07-73a5e6d0f3a8
# 2  2024-10-01    -5.00  66fc88e6-3301-424a-89d9-bcf35c957e5d
# 3  2024-10-03   400.00  66feda33-7263-4912-a915-91dc74e17517
# 4  2024-10-03  -114.18  66feda78-8c5b-4396-96a3-f64b12c108a8
# 5  2024-10-04    -9.00  670009eb-05db-4625-99df-6dcd66485b9f
# 6  2024-10-05  1000.00  67012873-e05e-4eb2-a8af-42fa95bf1045
# 7  2024-10-05 -1000.00  67019553-fd60-4499-bf14-3a7aa21ac0f2
# 8  2024-10-06  -158.42  6702e898-60d9-4f23-9e7d-88c7a745fc48
# 9  2024-10-07   -29.90  6703fbdb-ee0a-4c1f-ae61-a111a8227cc7
# 10 2024-10-07    -9.00  6703fd2a-5ae2-4919-94d1-50839fb1ab24
# 11 2024-10-07   -10.00  67043517-2796-40ed-bf4c-999f7b611e76
# 12 2024-10-08   -20.00  67055022-6f89-4598-bd5c-72fa52ba9ef9
# 13 2024-10-08   300.00  6705c0c3-8baf-4c3b-9923-614f10512b9e
# ...

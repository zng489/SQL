# %%
pip install duckdb
# Out:
# ...
#   Using cached duckdb-1.2.0-cp312-cp312-win_amd64.whl.metadata (995 bytes)
# Using cached duckdb-1.2.0-cp312-cp312-win_amd64.whl (11.4 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install duckdb pandas
pip install duckdb

# %%
import duckdb
import pandas
import pandas as pd

# Create a Pandas dataframe

###############################################################################################################
# Specify the path to your Snappy-compressed Parquet file
parquet_file_path = r'CD_UF=53'

# Read Parquet file into a pandas DataFrame
my_df = pd.read_parquet(parquet_file_path)
# print(my_df)
###############################################################################################################

# create the table "my_table" from the DataFrame "my_df"
# Note: duckdb.sql connects to the default in-memory database connection
duckdb.sql("DROP TABLE IF EXISTS my_table")


# insert into the table "my_table" from the DataFrame "my_df"
duckdb.sql("CREATE TABLE my_table AS SELECT * FROM my_df")


# insert into the table "my_table" from the DataFrame "my_df"
## duckdb.sql("SELECT * FROM my_table")


# Two kind of ways, how to connect using duckdb

###############################################################################################################
# import duckdb

# Connect to the database
# con = duckdb.connect(database='your_database.db')

# Execute the query
# result = con.execute("SELECT COLUMN_NAME FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'my_table'")
###############################################################################################################

result = duckdb.sql("SELECT COLUMN_NAME FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'my_table'")

rows = result.fetchall()

# Extract column names from the result
column_names = [row[0] for row in rows]

# Print or use the column names as needed
# print(column_names)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
#duckdb.sql("ALTER TABLE 'my_table' ADD COLUMN ANO VARCHAR(50) DEFAULT '2022'")
#duckdb.sql("SELECT * FROM my_table")

#duckdb.sql("ALTER TABLE my_table ADD COLUMN ANO VARCHAR(50) DEFAULT '2022'; SELECT * FROM my_table")

# %%
#duckdb.sql("ALTER TABLE 'my_table' ADD COLUMN ANO VARCHAR(50) DEFAULT '2022'")
#duckdb.sql("SELECT * FROM my_table")

#duckdb.sql("ALTER TABLE my_table ADD COLUMN ANO VARCHAR(50) DEFAULT '2022'; SELECT * FROM my_table")

duckdb.sql('''ALTER TABLE my_table ADD COLUMN ANO VARCHAR(50) DEFAULT '2022';
           DROP TABLE IF EXISTS new_table ;
           CREATE TABLE new_table AS SELECT * FROM my_table''')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
duckdb.sql("SELECT * FROM new_table")
# Out:
# ┌──────────────┬──────────────────┬──────────────────────┬───┬─────────────────────┬──────────────────────┬─────────┐
# │ CD_MUNICIPIO │ CD_CNAE10_CLASSE │ FL_VINCULO_ATIVO_3…  │ … │   dh_insercao_trs   │  kv_process_control  │   ANO   │
# │   varchar    │     varchar      │        int32         │   │    timestamp_ns     │       varchar        │ varchar │
# ├──────────────┼──────────────────┼──────────────────────┼───┼─────────────────────┼──────────────────────┼─────────┤
# │ 530010       │ 80322            │                    1 │ … │ 2024-06-24 10:00:46 │ {"adf_factory_name…  │ 2022    │
# │ 530010       │ 85111            │                    1 │ … │ 2024-06-24 10:00:46 │ {"adf_factory_name…  │ 2022    │
# │ 530010       │ 80152            │                    1 │ … │ 2024-06-24 10:00:46 │ {"adf_factory_name…  │ 2022    │
# │ 530010       │ 85111            │                    1 │ … │ 2024-06-24 10:00:46 │ {"adf_factory_name…  │ 2022    │
# ...

# %%
duckdb.sql('''SELECT DISTINCT column1, column2, FROM table_name;

# %%
duckdb.sql('''SELECT DISTINCT ID_CPF FROM new_table''')
# Out:
# ┌────────┐
# │ ID_CPF │
# │ int32  │
# ├────────┤
# │   NULL │
# └────────┘

# %%
#duckdb.sql('''SELECT LPAD(ID_CPF::text, 11, '0') AS ID_CPF FROM new_table''')

duckdb.sql('''SELECT LPAD(CD_MUNICIPIO::text, 11, '0') AS CD_MUNICIPIO FROM new_table''')
# Out:
# ┌────────────────────────┐
# │      CD_MUNICIPIO      │
# │        varchar         │
# ├────────────────────────┤
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │      ·                 │
# │      ·                 │
# │      ·                 │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# │ 00000530010            │
# ├────────────────────────┤
# │         ? rows         │
# │ (>9999 rows, 20 shown) │
# └────────────────────────┘

# %%
duckdb.sql("SELECT * FROM new_table WHERE FL_VINCULO_ATIVO_3112 == '1'")

SELECT LPAD(ID_CPF::text, 11, '0') AS ID_CPF
FROM your_table;
# Out:
# ┌──────────────┬──────────────────┬──────────────────────┬───┬─────────────────────┬──────────────────────┬─────────┐
# │ CD_MUNICIPIO │ CD_CNAE10_CLASSE │ FL_VINCULO_ATIVO_3…  │ … │   dh_insercao_trs   │  kv_process_control  │   ANO   │
# │   varchar    │     varchar      │        int32         │   │    timestamp_ns     │       varchar        │ varchar │
# ├──────────────┼──────────────────┼──────────────────────┼───┼─────────────────────┼──────────────────────┼─────────┤
# │ 530010       │ 80322            │                    1 │ … │ 2024-06-24 10:00:46 │ {"adf_factory_name…  │ 2022    │
# │ 530010       │ 85111            │                    1 │ … │ 2024-06-24 10:00:46 │ {"adf_factory_name…  │ 2022    │
# │ 530010       │ 80152            │                    1 │ … │ 2024-06-24 10:00:46 │ {"adf_factory_name…  │ 2022    │
# │ 530010       │ 85111            │                    1 │ … │ 2024-06-24 10:00:46 │ {"adf_factory_name…  │ 2022    │
# ...

# %%
SELECT column1, column2, ...
FROM table_name
WHERE condition;

# %%
df_2008_2018 = (
  df_2008_2018\
  .filter(col('FL_VINCULO_ATIVO_3112') == '1')\
  .withColumn('ID_CPF', lpad(col('ID_CPF'),11,'0'))\
  .withColumn('ID_CNPJ_CEI',f.lpad(f.col('ID_CNPJ_CEI'),14,'0'))\
  .withColumn('CD_CNAE20_DIVISAO', f.substring(f.col('CD_CNAE20_SUBCLASSE'),1,2))\
)

# %%
import duckdb

# Connect to the database
con = duckdb.connect(database='your_database.db')

# Execute the query
result = con.execute("SELECT COLUMN_NAME FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'my_table'")

# Fetch all rows (results)
column_names = result.fetchall()

# Extract column names from the result
column_names = [row[0] for row in column_names]

# Print or use the column names as needed
print(column_names)
# Out:
# []

# %%
df_2008_2018 = df_rais_vinculo2008a2018
df_2008_2018 = df_2008_2018.where(col('ANO').isin(ANOS))

# %%
duckdb.sql("SELECT 'CD_MUNICIPIO' FROM my_table")
# Out:
# ┌────────────────────────┐
# │     'CD_MUNICIPIO'     │
# │        varchar         │
# ├────────────────────────┤
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │      ·                 │
# │      ·                 │
# │      ·                 │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# │ CD_MUNICIPIO           │
# ├────────────────────────┤
# │         ? rows         │
# │ (>9999 rows, 20 shown) │
# └────────────────────────┘

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------- ------------------------------ 2.9/12.6 MB 18.6 MB/s eta 0:00:01
#    ------------------ --------------------- 5.8/12.6 MB 16.0 MB/s eta 0:00:01
#    ------------------------- -------------- 8.1/12.6 MB 14.4 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.6 MB 12.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 10.4 MB/s eta 0:00:00
# ...
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# ...

# %%
import duckdb
import pandas as pd

# %%
token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..iSu9kJu8kDTQL_KVcRwE5nh8lgbSEcZX_K81pfPvBcQ'
token
conn = duckdb.connect("md:[my_db]?[motherduck_token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..iSu9kJu8kDTQL_KVcRwE5nh8lgbSEcZX_K81pfPvBcQ]&saas_mode=true")
#conn = duckdb.connect(f"md:[<database_name>]?{token}&saas_mode=true")
# Out:
# ---------------------------------------------------------------------------
# InvalidInputException                     Traceback (most recent call last)
# Cell In[8], line 3
#       1 token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..iSu9kJu8kDTQL_KVcRwE5nh8lgbSEcZX_K81pfPvBcQ'
#       2 token
# ...

# %%
import duckdb

# Your token (replace with your actual token)
token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..iSu9kJu8kDTQL_KVcRwE5nh8lgbSEcZX_K81pfPvBcQ'

# Connect to MotherDuck with the specified database and token
#conn = duckdb.connect(f"md:my_db?motherduck_token={token}")
conn = duckdb.connect(f'md:?motherduck_token={token}')

# Run a query
# result = conn.execute("SELECT * FROM sample_data.hn.hacker_news LIMIT 10").fetchall()
###result = conn.execute("SELECT * FROM sample_data.hn.hacker_news LIMIT 10").fetchdf()

# %%
result = conn.execute("SELECT * FROM sample_data.hn.hacker_news LIMIT 10").fetchdf()

# %%
conn.sql("CREATE TABLE IF NOT EXISTS my_db.main.test AS SELECT * FROM sample_data.hn.hacker_news")

# %%
con.sql("CREATE TABLE IF NOT EXISTS github.github_commits AS SELECT * FROM df")

# %%
# Delete the table (if it exists)
conn.execute("DROP TABLE IF EXISTS sample_data.hn.hacker_news")
print("Table deleted successfully (if it existed).")

# %%
#!pip install duckdb==1.2.0

# %%
import duckdb

# Create connection to your default database
conn = duckdb.connect("md:my_db")

# Run query
conn.sql("CREATE TABLE items (item VARCHAR, value DECIMAL(10, 2), count INTEGER)")
conn.sql("INSERT INTO items VALUES ('jeans', 20.0, 1), ('hammer', 42.2, 2)")
res = conn.sql("SELECT * FROM items")
# Out:
# ---------------------------------------------------------------------------
# InvalidInputException                     Traceback (most recent call last)
# Cell In[3], line 4
#       1 import duckdb
#       3 # Create connection to your default database
# ----> 4 conn = duckdb.connect("md:my_db")
#       6 # Run query
#       7 conn.sql("CREATE TABLE items (item VARCHAR, value DECIMAL(10, 2), count INTEGER)")
#
# InvalidInputException: Invalid Input Error: Initialization function "motherduck_init" from file "C:\Users\PC\.duckdb\extensions\v1.2.0\windows_amd64\motherduck.duckdb_extension" threw an exception: "Initialization function "motherduck_init" from file "C:\Users\PC\.duckdb\extensions\v1.2.0\windows_amd64\motherduck.v1.2.0-2025-02-148.duckdb_extension" threw an exception: "Cannot connect to MotherDuck server: no token provided. For more info, see https://motherduck.com/docs/key-tasks/authenticating-to-motherduck""

# %%
# !pip install --upgrade duckdb

# %%
import duckdb

# Path to the manually downloaded extension file
extension_path = r"C:\Users\PC\Downloads\motherduck.duckdb_extension.gz"

# Connect to DuckDB
conn = duckdb.connect()

# Install and load the extension
conn.execute(f"INSTALL '{extension_path}'")
conn.execute("LOAD motherduck")

# Test the connection
conn.execute("SELECT * FROM md:my_db")
print(conn.fetchall())
# Out:
# ---------------------------------------------------------------------------
# InvalidInputException                     Traceback (most recent call last)
# Cell In[13], line 11
#       9 # Install and load the extension
#      10 conn.execute(f"INSTALL '{extension_path}'")
# ---> 11 conn.execute("LOAD motherduck")
#      13 # Test the connection
#      14 conn.execute("SELECT * FROM md:my_db")
#
# InvalidInputException: Invalid Input Error: Initialization function "motherduck_init" from file "C:\Users\PC\.duckdb\extensions\v1.1.3\windows_amd64\motherduck.duckdb_extension" threw an exception: "Failed to install extension from 'http://ext.motherduck.com/v1.1.3/windows_amd64/motherduck.v1.1.3-2025-01-237.duckdb_extension.gz': '{"exception_type":"IO","exception_message":"Failed to download \"http://ext.motherduck.com/v1.1.3/windows_amd64/motherduck.v1.1.3-2025-01-237.duckdb_extension.gz\". Status code \"503\": Success (no error)"}'"
